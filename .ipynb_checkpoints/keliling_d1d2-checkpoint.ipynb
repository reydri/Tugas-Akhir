# %%
import cv2
import numpy as np
from skimage import io
from PIL import Image
import pandas as pd
import glob
import os
from matplotlib import pyplot as plt
from pprint import pprint as pp

path_in = 'crop/*'
path_out = 'outxx'
window_name = 'cropxx'
size_max_image = 500
debug_mode = True
data = pd.read_csv('datasetkeliling.csv')
def show_image(image, window_name):
    # Show image
    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.imshow(window_name, image)
    image_width, image_height = get_image_width_height(image)
    cv2.resizeWindow(window_name, image_width, image_height)

    # Wait before closing
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
def get_image_width_height(image):
    image_width = image.shape[1]  # current image's width
    image_height = image.shape[0]  # current image's height
    return image_width, image_height

# %%
keliling = []
for file_iterator in glob.iglob(path_in):
    image = cv2.imread(file_iterator)
    image_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
    image_y = np.zeros(image_yuv.shape[0:2], np.uint8)
    image_y[:, :] = image_yuv[:, :, 0]

    image_blurred = cv2.GaussianBlur(image_y, (3, 3), 0)
    image_blurred = cv2.GaussianBlur(image_blurred, (3, 3), 0)
    #image_blurred = cv2.GaussianBlur(image_blurred, (3, 3), 0)
    #if (debug_mode):  show_image(image_blurred, window_name)

    # Apply canny edge-detector
    edges = cv2.Canny(image_blurred, 0, 390, apertureSize=3)
    #if (debug_mode):  show_image(edges, window_name)
    
    kel = 0
    for i in range(len(edges)):
        for j in range(len(edges[1])):
            if edges[i][j] == 255:
                kel += 1
    keliling.append(kel)
a = data["keliling"]
data2 = pd.DataFrame(keliling, columns=['keliling'])
if not a.all():
    data = pd.concat([data, data2], axis=1)
data
# Out:
#             r          g          b  keliling
# 0   71.547840  71.379321  67.611420       321
# 1   67.802165  68.359462  71.488615       248
# 2   71.757411  71.464610  69.369328       253
# 3   52.362839  52.722089  50.612839       200
# 4   75.371930  74.097856  73.974659       203
# ..        ...        ...        ...       ...
# 95  72.665714  74.663673  64.708163       186
# 96  47.699488  49.546888  42.306053       186
# 97  61.558462  62.788462  57.181923       238
# 98  71.466013  70.416993  62.781699       186
# 99  76.942348  73.849406  66.636618       225
#
# [100 rows x 4 columns]

# %%
data.to_csv('datasetkeliling.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-fee7c5d8b9d5> in <module>
# ----> 1 data.to_csv('datasetkeliling.csv')
#
# d:\python 3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# d:\python 3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# d:\python 3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'datasetkeliling.csv'
